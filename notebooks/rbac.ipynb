# %%
from passlib.context import CryptContext
pwd = CryptContext(schemes=["bcrypt"], deprecated="auto")
print(pwd.hash("admin"))
print(pwd.hash("nemesisSOF2025"))
# Out:
# (trapped) error reading bcrypt version
# Traceback (most recent call last):
#   File "/Users/ebezerra/miniconda3/envs/nemesis/lib/python3.11/site-packages/passlib/handlers/bcrypt.py", line 620, in _load_backend_mixin
#     version = _bcrypt.__about__.__version__
#               ^^^^^^^^^^^^^^^^^
# AttributeError: module 'bcrypt' has no attribute '__about__'
# $2b$12$t4.Vlk0vHKMrEIsk06qEv.oFV19mDhMBkQ1S3mClbH7mn/nkIbnRK
# $2b$12$aqJxeO.NT3PEbEaqCirITOn8zN7n.wW.ZxrO5HO.HlO4GrNaHBDQK

# %%
python - <<'PY'
from passlib.context import CryptContext
pwd = CryptContext(schemes=["bcrypt"], deprecated="auto")
print(pwd.hash("admin"))
PY

# %%
INSERT INTO public.users (username, password_hash) VALUES
  ('admin', '$2b$12$t4.Vlk0vHKMrEIsk06qEv.oFV19mDhMBkQ1S3mClbH7mn/nkIbnRK'),
  ('avaliador', '$2b$12$aqJxeO.NT3PEbEaqCirITOn8zN7n.wW.ZxrO5HO.HlO4GrNaHBDQK');
